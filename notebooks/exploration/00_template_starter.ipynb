# %% [markdown]
# # Serendipity Maximizer - Exploration Starter
#
# **Status**: Exploration only. Port stable logic to `src/` per AI-RULES.md.
#
# Use this for initial recombination ideas, scoring experiments, and LangGraph supervisor prototyping.

# %%
from dotenv import load_dotenv
load_dotenv()

print("Exploration environment ready. Remember: no production code here!")
